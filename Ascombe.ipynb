# %% [markdown]
# <a href="https://colab.research.google.com/github/lazarogibert/Repositorio/blob/main/Ascombe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from re import X
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

X1 = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0]
Y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
X1a = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0, 16]
Y1a = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68, 8]
X1b = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0, 8]
Y1b = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68, 6]
X1c = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0, 16]
Y1c = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68, 10]
X1d = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0, 16]
Y1d = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68, 6]

datos = pd.DataFrame({'X1':X1, 'Y1': Y1})
datos2 = pd.DataFrame({'X1a':X1a, 'Y1a': Y1a})
datos3 = pd.DataFrame({'X1b':X1b, 'Y1b': Y1b})
datos4 = pd.DataFrame({'X1c':X1c, 'Y1c': Y1c})
datos5 = pd.DataFrame({'X1d':X1d, 'Y1d': Y1d})
sns.set(style="ticks")
g = sns.lmplot(x="X1", y="Y1", data=datos)
a =sns.lmplot(x="X1a", y="Y1a", data=datos2)
b =sns.lmplot(x="X1b", y="Y1b", data=datos3)
c =sns.lmplot(x="X1c", y="Y1c", data=datos4)
d =sns.lmplot(x="X1d", y="Y1d", data=datos5)
#sns.lmplot(x="X1", y="Y1", col= "X1", hue="Y1", data=datos,
 #              col_wrap=2, ci=None, palette="muted", height=4,
 #              scatter_kws={"s": 50, "alpha": 1});
#print(datos)
#print("Este es el grafico del dataset original")
#plt.plot(X1,Y1)
#plt.title("Dataset original")
#plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

X2 = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0]
Y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
X2a = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0, 16]
Y2a = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74, 8]
X2b = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0, 8]
Y2b = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74, 6]
X2c = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0, 16]
Y2c = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74, 10]
X2d = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0, 16]
Y2d = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74, 6]

datos = pd.DataFrame({'X2':X2, 'Y2': Y2})
datos2 = pd.DataFrame({'X2a':X2a, 'Y2a': Y2a})
datos3 = pd.DataFrame({'X2b':X2b, 'Y2b': Y2b})
datos4 = pd.DataFrame({'X2c':X2c, 'Y2c': Y2c})
datos5 = pd.DataFrame({'X2d':X2d, 'Y2d': Y2d})
sns.set(style="ticks")
g = sns.lmplot(x="X2", y="Y2", data=datos)
a =sns.lmplot(x="X2a", y="Y2a", data=datos2)
b =sns.lmplot(x="X2b", y="Y2b", data=datos3)
c =sns.lmplot(x="X2c", y="Y2c", data=datos4)
d =sns.lmplot(x="X2d", y="Y2d", data=datos5)

# %% [markdown]
# Se puede observar que independientemente de que estos datos se comportan aparentemente de la misma manera estadisticamente una vez se grafican son muy diferentes. Para introducir los nuevos puntos habria que graficar cada dataset con los puntos nuevos y ubicarlos en el dataset que menos difiera del original.
